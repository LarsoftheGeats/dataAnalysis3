# %% [markdown]
# # Unit 3 Project - Exploratory Data Analysis

# %% [markdown]
# ## Part 1 - Univariate Analysis - Visualization

# %% [markdown]
# ### Step 1 - Open Jupyter Notebook in New Virtual Environment

# %% [markdown]
# ###### This step should have been completed prior to opening the Jupyter Notebook. If it was not, create and activate your virtual environment, then restart your notebook within the venv.

# %% [markdown]
# ### Step 2 - Load DataFrame and Explore Dataset

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %%
# import pandas and numpy
import pandas as pd
import numpy as np

# %%
# load salary.csv into dataframe
#Since this is already clean I'm not loading as raw, but just as the salaryname
df=pd.read_csv("salary.csv")

# %%
# look at first few values of dataframe
df.head()
# Out:
#    age gender    education  industry  industry_experience       salary
# 0   19   Male  high school  business                    0  33640.60752
# 1   21   Male  high school  business                    2  43554.24216
# 2   19   Male  high school  business                    0  39795.29424
# 3   22   Male  high school  business                    1  51102.98856
# 4   21   Male  high school  business                    1  32809.57056

# %%
# look at basic dataframe info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25439 entries, 0 to 25438
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  25439 non-null  int64
#  1   gender               25439 non-null  object
#  2   education            25439 non-null  object
#  3   industry             25439 non-null  object
#  4   industry_experience  25439 non-null  int64
#  5   salary               25439 non-null  float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#                 age  industry_experience         salary
# count  25439.000000         25439.000000   25439.000000
# mean      46.219466            18.418413  101416.000070
# std       12.758662             8.916748   26136.687123
# min       18.000000             0.000000   28054.080000
# 25%       36.000000            12.000000   84621.294048
# 50%       47.000000            19.000000  101148.480000
# 75%       57.000000            25.000000  119828.075728
# max       67.000000            35.000000  175223.321900

# %% [markdown]
# ### Step 3 - Review Types of Basic Univariate Plots

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Fill in blanks with a brief description of each plot type:
#
#
# - Histogram
# > [Breaks the data up into bins, and shows the count for each bin, gives you a sense of shape of the data.]
# - Density Plot / KDE
# > [Like a histogram but estimates are made of a connecting function called the kernel, to smoothly interpolate between discrete bins.  ]
# - Bar Chart
# > [Shows the numeric value for various categories.  ]
# - Line Plot
# > [Show the values by index and then connects them sequentially with a line.   Good for time indexed things that have trends]
# - Univariate scatter plot
# > [Plot a dot for every (x,y) pair]
# - Violin Plot
# > [Rotates and doubles the Kernel Density function to show the shape of the data in every category]
# - Box Plot
# > [Shows a central tendency of the data, with the median shown, as well as 2-boxes demonstrating the middle 50%.  And then 2-whiskers showing the trended maximum for a value.  Values outside the whiskers are shown as dots representing outliers]
# - Pie Chart
# > [Represents the data as a percentage of a whole.  The % is proportional to the slice of the circle the data takes up]
# - Rug Plot
# > [Similar to a Density plot, but each value gits an arbitrarily sized tick corresponding to its index value.  The rug becomes "thicker" when there's a lot of data.  Hard to read, generally unused.]

# %% [markdown]
# ### Step 4 - Choose Which Plot(s) You Will Use for Each Variable

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Take a moment to plan what types of plots you will make for each variable
#
#
# - age
# >Histogram.  I like seeing the shape of the age values.  The KDE might be even more informative  Age vs count of workers
# - gender
# >A pie chart.  There aren't that many gender categories, so it shows up cleanly as a percentage
# - education
# >Bar Graph.  Plotting percentage by category
# - industry
# >Bar Chart Count vs category
# - industry experience
# >Density Plot/ KDE
# - salary
# >Histogram Count vs salary/year

# %% [markdown]
# ### Step 5 - Create Plots for Each Variable in Dataset

# %%
# import matplotlib
import matplotlib.pyplot as plt

# import seaborn
import seaborn as sns

# set standard plot type as seaborn plot
sns.set()



# write command for plots to appear in jupyter cells automatically
# %matplotlib inline

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# ### Plot for 'age' column

# %%
# create plot for age column
#note I originally used distplot, moved to displot
sns.distplot(df['age'], kde=True, bins=10, hist=True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# ##### Insights:
#
# You can clearly see people entering the workforce at 18 and leaving at 70.  The KDE overlay indicates spikes in the data which may not be captured by the lumped up nature of the bins.

# %% [markdown]
# ### Plot for 'industry' column

# %%
# create plot for industry column
fig = plt.figure()
y=df['industry'].value_counts()
x=df['industry'].unique()
fig, ax= plt.subplots()
ax.bar(x,y, width=.8, edgecolor="white", linewidth=0.2)
ax.set (ylim=(5000,6500))
#I chose to zoom in
# Out:
# [(5000.0, 6500.0)]

# %% [markdown]
# ##### Insights:
# I needed to zoom in to see any distinction between the industries  The big thing we see is that the data has a roughly even sampling from industries it hose

# %% [markdown]
# ### Plot for 'salary' column

# %%
# create plot for salary column
fig=sns.distplot(df['salary'], kde=False, bins=15, hist=True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##### Insights:
#
# This shows some central tendencies that look more like a standard normal curve

# %% [markdown]
# ### Plot for 'industry_experience' column

# %%
# create plot for industry experience column
sns.distplot(df['age']-18, kde=True, bins=15, hist=False, color='red')
sns.distplot(df['industry_experience'], kde=True, bins=15, hist=True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='industry_experience', ylabel='Density'>

# %% [markdown]
# ##### Insights:
#
#
# Whats fascinating is that even though the data looks close to a normal curve, the age distribution from a previous look a more end loaded distribution.  The difference clearly suggesting job switches.  As you can see in the above, the above when we adjust down the age by 18, we have an high-weighted age distribution which the industry-experience data doesn't have.

# %% [markdown]
# ### Plot for 'education' column

# %%
# create plot for education levels
sns.countplot(x='education', data=df)
# Out:
# <AxesSubplot:xlabel='education', ylabel='count'>

# %% [markdown]
# ##### Insights:
#
# The Sample is  heavily weighted towards those that have completed a degree

# %% [markdown]
# ### Plot for 'gender' column

# %%
dummy={'Gender':['male','female'],'count':[12720,12720]}
df1=pd.DataFrame(dummy)
fig, ax= plt.subplots()
sns.barplot(df1['Gender'],df1['count'],color='red')
sns.countplot(x='gender', data=df,alpha=.8)
ax.set (ylim=(12100,12800))
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [(12100.0, 12800.0)]

# %%
x = df.groupby('gender')['gender'].count()
colors = plt.get_cmap('Blues')(np.linspace(0.2, 0.7, len(x)))
x

fig, ax = plt.subplots()
ax.pie(x, colors=colors, radius=3, center=(4, 4),
       wedgeprops={"linewidth": 1, "edgecolor": "white"}, frame=True, autopct='%.0f%%')

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %% [markdown]
# ##### Insights:
#
# The big insight is that the difference samples between male and female is miniscule.  On the bar plot above I graphed a 50% in both categories as an overlay, and the color change is just a tiny slice of the 2 samples.

# %% [markdown]
# ## Part 2 - Summary Statistics

# %% [markdown]
# ### Step 1 - Review Summary Statistics

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# - mean
# > Average.  That is total valuation or "score" over all samples divided by all samples.
# - median
# > A middle point.  The point at which 1/2 the samples are greater than or equal to a value, and 1/2 are less than that value
# - mode
# > The most common value or measurement.
# - central tendency
# > A value that describes the center of the dataset.  For instance mean is a bad descriptor of income, but more reasonable for height since the long tail in income isn't limited by biology.
# - distribution
# > The shape of the graph, for instance standard normal, Poisson, exponential.
# - variance
# > A value that quantifies how widely spaced things are from the mean.  A measure of "spread"
# - standard deviation
# > Multiple meanings, but it's derived from variance and indicates how much something is spread from the mean.  Also within a  standard deviation we have about ~ 68% of the samples or observations

# %% [markdown]
# ### Step 2 - Find  & Report Summary Statistics For Numeric Variables

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Age Summary Statistics

# %%
# use .describe to get summary statistics for age column

df['age'].describe()
# Out:
# count    25439.000000
# mean        46.219466
# std         12.758662
# min         18.000000
# 25%         36.000000
# 50%         47.000000
# 75%         57.000000
# max         67.000000
# Name: age, dtype: float64

# %%
# create boxplot to visualize age summary statistics
plt.figure(figsize=(9,9))
plt.title('Boxplot of age')
plt.boxplot(df['age'], labels=['age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x278185d4b20>,
#   <matplotlib.lines.Line2D at 0x278185d4df0>],
#  'caps': [<matplotlib.lines.Line2D at 0x278185e2100>,
#   <matplotlib.lines.Line2D at 0x278185e23d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x278185d4850>],
#  'medians': [<matplotlib.lines.Line2D at 0x278185e26a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x278185e2970>],
#  'means': []}

# %% [markdown]
# - age **mean**
# > The mean age is [46.2]
# - age **median**
# > The median age is [47]
# - age **minimum**
# > The minimum age is [18]
# - age **maximum**
# > The maximum age is [67]
# - age **standard deviation**
# > The standard deviation is [12..7]

# %% [markdown]
# ###### Reflection: How did mean and median differ above? Why do you think that is?
#
# [your answer here]

# %% [markdown]
# #### Salary Summary Statistics

# %%
# use .describe to get summary statistics for salary
df['salary'].describe()
# Out:
# count     25439.000000
# mean     101416.000070
# std       26136.687123
# min       28054.080000
# 25%       84621.294048
# 50%      101148.480000
# 75%      119828.075728
# max      175223.321900
# Name: salary, dtype: float64

# %%
# create boxplot to visualize salary summary statistics
df['salary'].median()
fig = plt.figure(figsize=(6,6))
plt.title('Boxplot of salaries')
plt.boxplot(df['salary'], labels=['salary'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27818637c40>,
#   <matplotlib.lines.Line2D at 0x27818637f10>],
#  'caps': [<matplotlib.lines.Line2D at 0x27818647220>,
#   <matplotlib.lines.Line2D at 0x278186474f0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x27818637970>],
#  'medians': [<matplotlib.lines.Line2D at 0x278186477c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27818647a90>],
#  'means': []}

# %%
df['salary'].median()
# Out:
# 101148.48

# %% [markdown]
# - Salary **mean**
# > The mean salary is 101,400]
# - Salary **median**
# > The median salary is [101,100]
# - Salary **minimum**
# > The minimum salary is [28050]
# - Salary **maximum**
# > The maximum salary is [175200]
# - Salary **standard deviation**
# > The standard deviation is [26,100]

# %% [markdown]
# ###### Reflection: How did mean and median differ above? Why do you think that is?
#
# [In statistics this  is often called the long tail.  There is no upper limit to how much you can earn, but there is a lower limit in that for practical purposes negative income is impossible.]

# %% [markdown]
# ### Step 3 - Find Salary Summary Statistics By Industry

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %%
# use groupby() and describe() to get salary summary statistics by industry
df.groupby(['industry'])['salary'].describe()
# Out:
#              count           mean           std          min           25%  \
# industry
# business    6367.0   98296.471387  24822.138864  29340.67968  82482.816000
# finance     6383.0  102838.541755  26344.729075  30747.52224  86224.406400
# healthcare  6307.0   94767.547447  23696.008298  28054.08000  79538.185000
# technology  6382.0  109675.753478  27127.404233  32704.34400  92223.969112
#
#                      50%            75%           max
# industry
# business     98200.01048  116110.250464  159030.78048
# finance     102692.33568  122237.832000  166370.21852
# healthcare   94728.96000  112058.784000  152775.98600
# technology  109130.17575  129758.177182  175223.32190

# %%
# create visualization with multiple boxplots to show salary summary statistics by industry
plt.figure(figsize=(6,6))
plt.title('Salary')

sns.boxplot(data=df, x='industry', y='salary')

plt.xlabel('Job_industry')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# ##### Insights:
#
# [We can that the technology field has the widest spread of the industries, as well as a higher minimu and median. Most of the other industries are much less distinguishable on the salary front.   ]

# %% [markdown]
# ### Step 4 - Find Salary Summary Statistics By Education

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %%
# use groupby() and describe() to get salary summary statistics by education level
df.groupby(['education'])['salary'].describe()
# Out:
#                     count           mean           std        min  \
# education
# bachelors degree  10972.0  100710.905311  20960.707146  40962.240
# high school         781.0   47602.924607  10556.975508  28054.080
# masters degree     8979.0  115583.500303  21594.533546  68037.024
# some college       4707.0   84962.702227  24994.963474  29030.208
#
#                            25%            50%           75%           max
# education
# bachelors degree  85154.097000   98829.004800  115799.14680  159790.23450
# high school       39832.128000   46255.446000   53930.62080   78486.86520
# masters degree    98782.553760  113936.908800  131988.10416  175223.32190
# some college      68385.261696   84824.902426  103041.44640  149241.93034

# %%
# create visualization with multiple boxplots to show salary summary statistics by education level
plt.figure(figsize=(6,6))
plt.title('Salary by education')

sns.boxplot(data=df, x='education', y='salary')

plt.xlabel('education')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# ##### Insights:
#
# [At all levels higher education leads to higher salaries.  In fact moving up an educational step pushes the median above the the previous levels top 2nd quartile.  ]

# %% [markdown]
# ### Step 5 - Find Salary Summary Statistics by Gender

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %%
# use groupby() and describe() to get salary summary statistics by gender
df.groupby(['gender'])['salary'].describe()
# Out:
#           count           mean           std        min         25%  \
# gender
# Female  12730.0   98209.928810  24978.233860  28054.080  81938.1888
# Male    12709.0  104627.368954  26867.859585  29725.182  87625.1900
#
#                 50%          75%          max
# gender
# Female   98057.3880  115867.1844  163708.4064
# Male    104240.0788  123838.3008  175223.3219

# %%
# create visualization with multiple boxplots to show summary statistics by gender
plt.figure(figsize=(6,6))
plt.title('Salary by gender')

sns.boxplot(data=df, x='gender', y='salary')

plt.xlabel('gender')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# ##### Insights:
#
# [Males have a significantly higher spread of salaries, and also a higher minimum nd median and max.  ]
#
# ## Part 3 - Looking for Relationships in Data

# %% [markdown]
# ### Step 1 - Review Useful Tools for Bivariate Relationships

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Fill in the blanks below with brief explanations of each type of plot listed
#
# - **Categorical Data**
# > ***Contingency Table***
# >
# >[Not so much a plot, as a numerical representation that connects subcategories in one column with subcategories in another category.  For instance it might be useful to know Males and females in each industry]
# >
# > ***Clustered Bar Chart***
# >
# >[Clusters sub categories together by a broader category.  For instance we could see employment by industry and then subcategories would be education level but grouped by industry.  This lets you see related data next to each other but still compare it to different categories]
#
# - **Mixed Data**
# > ***Individual Value Plot***
# >
# >[Shows a dot for each observed value in a group.  It performs poorly in large data, but gives you a sense of where the data is clustered.   ]
# >
# > ***Strip Plot***
# >
# >[Shows a dot for each measurement at a value, works a bit like an individual value plot, but is a little more refined, and is best combined with a violin plot showing KDE]
#
# - **Quantitative Data**
# > ***Scatter plots***
# >
# > [Just a match between two columns of a data set, it plots a scattering of points all over the graph, can be good for estimating a regression line.  It shines best with the regression line included.  ]

# %% [markdown]
# ### Step 2 - Create Bivariate Plots & Tables

# %% [markdown]
# In the end of Part 2, you began looking at relationships between variables when you created boxplots which visualized the distribution of salary across different categories. In this step, you will make plots and visualizations to begin looking deeper for patterns and relationships between two variables.

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# ### Use the Pandas Crosstab() function to compare categorical variables

# %% [markdown]
# #### crosstab of gender and education

# %%
# use pd.crosstab to count number of managers at each education level, grouped by gender
crosstb=pd.crosstab(df.education, df.gender)
barplot=crosstb.plot.bar(rot=0)

# %% [markdown]
# ##### Insights:
#
# [This data set seems to have gone to great lengths to minimize differences between the genders, so there are almost identical numbers of men and women at each data level.]

# %% [markdown]
# ### Strip plot between age and education

# %%
# create strip plot for age and education
sns.stripplot(data=df, x='education', y='age', jitter=True, size=1, hue='gender')
# Out:
# <AxesSubplot:xlabel='education', ylabel='age'>

# %%
# sns.swarmplot(data=df, x='education', y='age', s=2)

# %% [markdown]
# ##### Insights:
#
# [This data set is too large to get much from strip plot.  But there are some things e can glean.  The data stops around 67 or 68 just after retirement.  Also we've got gaps at the bottom of the data for the higher education degrees which correspond reasonably well with the time required to get that degree.  So since it takes 4 years to get a Bachelor's degree we shouldn't expect much data from degree holders under 22 or so.  Jitter didn't improve  this at all.]

# %% [markdown]
# ### Scatterplot for age and salary

# %%
# create scatterplot for age and salary
sns.scatterplot(data=df, x='age', y='salary')
# Out:
# <AxesSubplot:xlabel='age', ylabel='salary'>

# %% [markdown]
# ##### Insights:
#
# [The data indicates that older workers are generally able to command a higher salary]

# %% [markdown]
# ### Scatterplot for industry experience and salary

# %%
# create scatterplot for industry experience and salary
sns.scatterplot(data=df, x='industry_experience', y='salary')
# Out:
# <AxesSubplot:xlabel='industry_experience', ylabel='salary'>

# %% [markdown]
# ##### Insights:
#
# [As with age, salary increases with industry experience.  ]

# %% [markdown]
# ### Step 3 - Pick Two More Bivariate Relationships to Visualize

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %%
# create 1st visualization for bivariate relationship of your choice
sns.scatterplot(data=df, x='industry_experience', y='salary', hue='gender')
#not a new visualization, but instructive to see the difference between men and women on salary vs experience.
#This might be an instructive regression line to run.
# Out:
# <AxesSubplot:xlabel='industry_experience', ylabel='salary'>

# %%
# create 1st visualization for bivariate relationship of your choice
#I'm going to boxplot by industry vs salary grouped by gender
sns.boxplot(data=df, x='industry', y='salary', hue='gender')
# Out:
# <AxesSubplot:xlabel='industry', ylabel='salary'>

# %%
# create 2nd visualization for bivariate relationship of your choice
sns.boxplot(data=df, x='education', y='salary', hue='gender')
# Out:
# <AxesSubplot:xlabel='education', ylabel='salary'>

# %% [markdown]
# ## Part 4 - Correlation & Hypothesis Testing

# %% [markdown]
# ### Step 1 - Review Correlation

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Fill in blanks with brief description of the following terms:
#
#
# - **Correlation**
# > ***[How related two variables are to each other.  ]***
#
# - **Correlation Coefficient**
# >***[A measure of how related two series of data are.  Varies between -1, and 1 with numbers close to 0 indicating little to no relation between the two data sets.]***

# %% [markdown]
# ### Step 2 - Review Hypothesis Testing & P-Value

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Fill in blanks with brief description of the following terms:
#
# - **Hypothesis**
# > ***[An educated guess or prediction bout the world around you.  It also needs to be testable.  ]***
#
# - **Null Hypothesis**
# > ***[A claim that no difference exists between two things that the data is studying.]***
#
# - **P-Value**
# > ***[The probability that the observed sample could arise from a population in which the null hypothesis is true.  ]***

# %%
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Step 3 - Use Pearsonr & Spearmanr To Answer Questions About Correlation and P-Values

# %% [markdown]
# <h3 style='color:red;'> First, load 'salary_numeric.csv' - where education has been re-expressed as numeric variables.</h3>

# %%
# load salary_numeric.csv into dataframe where education levels have been re-expressed as numeric
numeric=pd.read_csv("salary_numeric.csv")
numeric.head()
# Out:
#    age gender  education  industry  industry_experience       salary
# 0   19   Male         12  business                    0  33640.60752
# 1   21   Male         12  business                    2  43554.24216
# 2   19   Male         12  business                    0  39795.29424
# 3   22   Male         12  business                    1  51102.98856
# 4   21   Male         12  business                    1  32809.57056

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %%
# import pearson and spearmanr methods from scipy.stats library
from scipy.stats import pearsonr, spearmanr

# %% [markdown]
# ### What is the correlation between salary and education?

# %%
#### Your Hypothesis = [My hypothesis is that higher education leads to higher salary]

# calculate correlation and pvalue of salary and education with spearmanr method
spearmanr(numeric['salary'],numeric['education'])
# Out:
# SpearmanrResult(correlation=0.47719759648149285, pvalue=0.0)

# %%
sns.heatmap(numeric.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# [The relation is not as strong as I had thought.  This would be only moderately correlated  Using the heatmap data above I can easily see that other things drive this more heavily

# %% [markdown]
# #### Are these results statistically significant? How do you know?

# %% [markdown]
# [yes.  The p-value is smaller than the .05 threshhold generally used for statistics.  So this indicates it's likely that any other sample we got would hvae similar results.  ]

# %% [markdown]
# ### What is the correlation between salary and age?

# %% [markdown]
# #### Your Hypothesis [I think salary from my previous views of the data that age and salary have a very strong relationship, and that increasing age very strongly leads to increased salary.]

# %%
# calculate correlation and pvalue of salary and age with pearsonr method
pearsonr(numeric['age'],numeric['salary'])
# Out:
# PearsonRResult(statistic=0.6631258539501858, pvalue=0.0)

# %% [markdown]
# [This is a stronger relationship, the short version of it is that salary increases as age increases.]

# %% [markdown]
# #### Are these results statistically significant? How do you know?

# %% [markdown]
# [yes.  The p-value has enough zeroes in front of it that there is a vanishingly small chance that the null hypthosis correctly describes the population]

# %% [markdown]
# ### What is the correlation between salary and industry experience?

# %% [markdown]
# #### Your Hypothesis = [Looking back at the graphs, I'm of the opinion that Industry Experience is the biggest driver in salary.  So I hypothesize that it will have the largest correlation.]

# %%
# calculate correlation and pvalue of salary and industry experience with pearsonr method
pearsonr(numeric['industry_experience'],numeric['salary'])
# Out:
# PearsonRResult(statistic=0.6206907635712202, pvalue=0.0)

# %% [markdown]
# [There is a relationship between industry experience and salary, but it is weaker than the relationship between age and salary ]

# %% [markdown]
# #### Are these results statistically significant? How do you know?

# %% [markdown]
# [Yes, the probability is small enough that we are in the rejection zone.  ]

# %% [markdown]
# ### Step 4 - Report Findings

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# ### What was the null hypothesis for the relationships between education and salary, age and salary, and industry experience and salary?

# %% [markdown]
# [The null hypothesis s that there is no statistical relationship between education and salary, salary and age, or salary and industry experience]

# %% [markdown]
# ### Can you reject the null hypothesis for any of the relationships you explored above?

# %% [markdown]
# [Yes, in all 3 cases we can reject the null hypothesis.  The statistical significance is enough below .001 that scipy doesn't bother to show any more zeroes.  Although in the case of education and salary, the correlation between the two values is moderate to weak.  ]

# %% [markdown]
# ## Part 5 - Multivariate Analysis

# %% [markdown]
# ### Step 1 - Review Types of Multivariate Analysis

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### Fill in the blanks with a brief description of each plot type
#
# - pairplots
# > [a graph that plots every combination of 2 categories against ech other with every pairing in the data represented by a dot.  So if we had 5 categories we would get 25 scatterplots shoing all possible combinations between these variables.  ]
# - paired scatter plots
# > [A scatter plot of 2 categories against each other, with every data point represented by a dot.   ]
# - correlation matrix
# > [a nxn table indicating the correlation of all the 2 vriable pairings]
# - heatmap
# > [a graphical representation of the correlation matrix.  ]

# %% [markdown]
# ### Step 2 - Create Pairplots for Dataset

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# #### pairplot of whole dataframe

# %%
# create pairplot of dataframe
sns.pairplot(numeric, hue='gender')

# %% [markdown]
# ##### Insights:
#
# [This offers a good first look at the data, so I can at a glance pick the interesting relationships to explore.  Right now I have salary vs age and salary vs industry experience side by side, so at a glance I can pick industry_experience as the best candidate to explain salary differenes.   ]

# %% [markdown]
# ### Step 3 - Create Other Multivariate Plots

# %%
################################### TO DO #########################################
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
# ### Correlation matrix

# %%
# use .corr() to create correlation matrix
numeric.corr()
# Out:
#                           age  education  industry_experience    salary
# age                  1.000000   0.358189             0.842555  0.663126
# education            0.358189   1.000000             0.348966  0.538828
# industry_experience  0.842555   0.348966             1.000000  0.620691
# salary               0.663126   0.538828             0.620691  1.000000

# %% [markdown]
# ### Heatmap of correlation matrix

# %%
# create heatmap visualization of correlation matrix
sns.heatmap(numeric.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(numeric.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Insights:
#
# [Cool warm offers the best test for me, but I can see that age and industry are probably the best candidates on the salary column for deeper exploration ]

# %% [markdown]
# #### Crosstab of average salary grouped by education and industry

# %%
# use pd.crosstab() to calculate mean salary in each industry grouped by education level
pd.crosstab(numeric.salary,numeric.education)
# Out:
# education     12  14  16  18
# salary
# 28054.08000    1   0   0   0
# 29030.20800    0   1   0   0
# 29224.80000    1   0   0   0
# 29340.67968    1   0   0   0
# 29725.18200    1   0   0   0
# ...           ..  ..  ..  ..
# 174355.55720   0   0   0   1
# 174368.58670   0   0   0   1
# 175035.69710   0   0   0   1
# 175096.93575   0   0   0   1
# 175223.32190   0   0   0   1
#
# [25185 rows x 4 columns]

# %% [markdown]
# #### Heatmap of crosstab of average salary grouped by education and industry

# %%
# save above result to new variable
crosstb=pd.crosstab(index=numeric.education,columns=numeric.industry,values=numeric.salary, aggfunc=np.mean)

# %%
# create heatmap with annotated mean salary in each industry and education level
sns.heatmap(crosstb)
# Out:
# <AxesSubplot:xlabel='industry', ylabel='education'>

# %% [markdown]
# ##### Insights:
#
# [Technology has the best average salaries, and masters have the best salaries across all industries ]

# %% [markdown]
# ### Step 4 - Report Findings

# %%
################################### TO DO #########################################
  
####### FOLLOW PROJECT INSTRUCTIONS TO COMPLETE THIS STEP IN THE CELLS BELOW ######

# %% [markdown]
#     Industry choice, years experience, and age all had a more pronounced effect on salary of managers than gender did.  Also it's useful to note that some of the tools we used at the end of the analysis are much quicker for a first cut data analysis than doing a deep dive, into every data pairing.  The KDE is a very powerful tool for getting a shape of univariate data that's being studied.
#
#     Additionally, I've noticed that a lot of data plans for plotting or cleaning often go by the wayside after we start to see how our data looks.  The exploratory component of EDA is quite literal, you might find yourself down a wrong path, and need to adjust for unexpected results.  Early on in the exploration, I'd thought we would be comparing differences across gender, and while that is still possible with this data that wasn't the analysis we

# %% [markdown]
# ###### Along the way throughout this project, you should have been taking notes on insights from your exploratory data analysis. Take some time in a markdown cell below to write a couple paragraphs summarizing any observations, insights, conclusions, or further questions you have based on the exploratory analysis you conducted this week.

# %% [markdown]
# [...]

# %% [markdown]
# ### Step 5 - Submit Project

# %% [markdown]
# ###### Push to GitHub, record brief code review video, and share links with Tech Lead and SME.
